# %%
from __future__ import print_function
import os
import numpy as np
import pandas as pd
#import json
import pylab as pl

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
DFdata = os.getenv('DFDATA')
print (DFdata)
# Out:
# /gws/open/NYCOpenData/nycopendata/data

# %%
path = DFdata + "/zkky-n5j3/1414246141/zkky-n5j3"

data = pd.read_csv(path, parse_dates = [0])
data.head()
# Out:
#   Neversink Date                Neversink Elevation  Neversink Storage  \
# 0          2005-03-01 16:00:00              1440.21              35570
# 1          2005-03-02 16:00:00              1440.22              35575
# 2          2005-03-03 16:00:00              1440.21              35570
# 3          2005-03-04 16:00:00              1440.21              35570
# 4          2005-03-05 16:00:00              1440.21              35570
#
#       Rondout Date               Rondout Elevation  Rondout Storage  \
# 0  03/01/2005 04:00:00 PM +0000             835.10          46757.0
# 1  03/02/2005 04:00:00 PM +0000             834.98          46678.0
# 2  03/03/2005 04:00:00 PM +0000             834.84          46585.0
# 3  03/04/2005 04:00:00 PM +0000             834.85          46592.0
# 4  03/05/2005 04:00:00 PM +0000             834.88          46612.0
#
#     Schoharie Date               Schoharie Elevation  Schoharie Storage  \
# ...

# %%
data2 = data.iloc[:,0:2]
data2.columns = ['date','value']
data2.head()
# Out:
#                  date    value
# 0 2005-03-01 16:00:00  1440.21
# 1 2005-03-02 16:00:00  1440.22
# 2 2005-03-03 16:00:00  1440.21
# 3 2005-03-04 16:00:00  1440.21
# 4 2005-03-05 16:00:00  1440.21

# %%
ax = data2.plot(x = 'date', y = 'value', alpha = 0.4, marker = 'o')
ax.set_title('plot')
pl.show()
